# %%
import os
import matplotlib.pyplot as plt

# %%
from tkinter import Tk, filedialog, Label
root = Tk()
Label(root, text="Select data folder")
folder_path = filedialog.askdirectory()
root.destroy()

# %%
from nmdr.spm import io as spmIO
filter = "STM_WTip_WSe2_SL333-Set2-Crystal2_"
data = spmIO.read_dir(folder_path, filter=filter, ext="sxm")
plt.imshow(data[0])
plt.show()
# Out:
# H:\anaconda3\envs\pyNMDR\lib\site-packages\pySPM\utils\misc.py:135: UserWarning: the library tqdm cannot be found. All progressbar will be disabled.
#   warn("the library tqdm cannot be found. All progressbar will be disabled.")

# %%
from nmdr.spm.process import flatten
data = flatten(data)
plt.imshow(data[0])
plt.show()
# Out:
# H:\anaconda3\envs\pyNMDR\lib\site-packages\spiepy\flatten.py:54: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m, _, _, _ = np.linalg.lstsq(g, z)
# SVD did not converge in Linear Least Squares
# SVD did not converge in Linear Least Squares
# SVD did not converge in Linear Least Squares
